# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
videos_train_df = pd.read_csv('CAvideos.csv')
videos_test_df = pd.read_csv('CAvideos.csv')

# %%
videos_train_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
videos_train_df.isnull()
# Out:
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# 5         False          False  False          False        False
# 6         False          False  False          False        False
# 7         False          False  False          False        False
# 8         False          False  False          False        False
# 9         False          False  False          False        False
# 10        False          False  False          False        False
# 11        False          False  False          False        False
# 12        False          False  False          False        False
# ...

# %%
sns.heatmap(videos_train_df.isnull())

# %%
videos_train_df.drop(['video_id','title','channel_title','publish_time','tags','thumbnail_link','description'],axis=1,inplace=True)

# %%
videos_train_df.head()
# Out:
#   trending_date  category_id     views    likes  dislikes  comment_count  \
# 0      17.14.11           10  17158579   787425     43420         125882
# 1      17.14.11           23   1014651   127794      1688          13030
# 2      17.14.11           23   3191434   146035      5339           8181
# 3      17.14.11           24   2095828   132239      1989          17518
# 4      17.14.11           10  33523622  1634130     21082          85067
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False

# %%
sns.heatmap(videos_train_df.isnull())
